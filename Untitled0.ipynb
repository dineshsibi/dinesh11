# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url='https://www.sportsadda.com/football/features/top-10-football-players-of-all-time'

# %%
this=requests.get(url)

# %%
BeautifulSoup(this.text,'html')
# Out:
# <!DOCTYPE html>
# ...
