# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url='https://www.worldometers.info/gdp/gdp-per-capita/'

# %%
gdp=requests.get(url)

# %%
soup=BeautifulSoup(gdp.text,'html')

# %%
table=soup.find('table')

# %%
heading=table.find_all('th')

# %%
heading_text=[title.text for title in heading]

# %%
heading_text
# Out:
# ['#',
#  'Country',
#  'GDP (PPP)  per capita  (2022)',
#  'GDP (nominal) per capita (2022) ',
#  'vs. World PPP  GDP per capita ($20,645)']

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=heading_text)

# %%
table_tr=table.find_all('tr')

# %%
for topIt in table_tr[1:]:
  row_content=topIt.find_all('td')
  row_data_cont=[data.text.strip() for data in row_content]

  length=len(df)
  df.loc[length]=row_data_cont

# %%
df
# Out:
#        #      Country GDP (PPP)  per capita  (2022)  \
# 0      1   Luxembourg                      $142,214
# 1      2    Singapore                      $127,565
# 2      3      Ireland                      $126,905
# 3      4       Norway                      $114,899
# 4      5        Qatar                      $114,648
# ..   ...          ...                           ...
# 185  179       Bhutan                          N.A.
# 186  179        Palau                          N.A.
# 187  179        Aruba                          N.A.
# 188  179         Cuba                          N.A.
# 189  179  Afghanistan                          N.A.
#
#     GDP (nominal) per capita (2022)  vs. World PPP  GDP per capita ($20,645)
# 0                           $125,935                                    689%
# 1                            $82,619                                    618%
# 2                           $103,570                                    615%
# ...

# %%
csv_file_name = 'Documents/my_dataframe1.csv'
df1.to_csv(csv_file_name, index=False)

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [#, Country, GDP (PPP)  per capita  (2022), GDP (nominal) per capita (2022) , vs. World PPP  GDP per capita ($20,645)]
# Index: []

# %%
df1=df.head(10)

# %%
df1
# Out:
#     #               Country GDP (PPP)  per capita  (2022)  \
# 0   1            Luxembourg                      $142,214
# 1   2             Singapore                      $127,565
# 2   3               Ireland                      $126,905
# 3   4                Norway                      $114,899
# 4   5                 Qatar                      $114,648
# 5   6  United Arab Emirates                       $87,729
# 6   7           Switzerland                       $83,598
# 7   8         United States                       $76,399
# 8   9               Denmark                       $74,005
# 9  10           Netherlands                       $69,577
#
#   GDP (nominal) per capita (2022)  vs. World PPP  GDP per capita ($20,645)
# 0                         $125,935                                    689%
# 1                          $82,619                                    618%
# 2                         $103,570                                    615%
# ...

# %%
pip install  matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 190 entries, 0 to 189
# Data columns (total 5 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   #                                        190 non-null    object
#  1   Country                                  190 non-null    object
#  2   GDP (PPP)  per capita  (2022)            190 non-null    object
#  3   GDP (nominal) per capita (2022)          190 non-null    object
#  4   vs. World PPP  GDP per capita ($20,645)  190 non-null    object
# dtypes: object(5)
# memory usage: 8.9+ KB

# %%
country= pd.read_csv('Documents/my_dataframe1.csv')

# %%
print(df)
# Out:
#        #      Country GDP (PPP)  per capita  (2022)  \
# 0      1   Luxembourg                      $142,214
# 1      2    Singapore                      $127,565
# 2      3      Ireland                      $126,905
# 3      4       Norway                      $114,899
# 4      5        Qatar                      $114,648
# ..   ...          ...                           ...
# 185  179       Bhutan                          N.A.
# 186  179        Palau                          N.A.
# 187  179        Aruba                          N.A.
# 188  179         Cuba                          N.A.
# 189  179  Afghanistan                          N.A.
#
#     GDP (nominal) per capita (2022)  vs. World PPP  GDP per capita ($20,645)
# 0                           $125,935                                    689%
# 1                            $82,619                                    618%
# 2                           $103,570                                    615%
# ...

# %%
sns.barplot(x='Country',y='GDP (PPP)  per capita  (2022)',data=country)
# Out:
# <Axes: xlabel='Country', ylabel='GDP (PPP)  per capita  (2022)'>

# %%
sns.displot(x='Country',y='GDP (PPP)  per capita  (2022)',data=country)

# %%
sns.lineplot(x='Country',y='GDP (PPP)  per capita  (2022)',data=country)
# Out:
# <Axes: xlabel='Country', ylabel='GDP (PPP)  per capita  (2022)'>

# %%
sns.countplot(x='GDP (PPP)  per capita  (2022)', data=country)
plt.xticks(rotation=45)
plt.title('Count Plot of Countries')
plt.show()

# %%
sns.histplot(country['GDP (PPP)  per capita  (2022)'], bins=10, kde=True)
plt.title('Distribution of GDP (PPP) per Capita')
plt.xticks(rotation=45)
plt.show()

# %%
sns.swarmplot(x='Country', y='GDP (PPP)  per capita  (2022)', data=country)
plt.xticks(rotation=45)
plt.title('Swarm Plot of GDP (PPP) per Capita by Country')
plt.show()
